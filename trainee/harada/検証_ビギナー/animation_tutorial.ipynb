# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()

ims = []

for i in range(10):
        rand = np.random.randn(100)     # 100個の乱数を生成
        con = 5
        #func = np.sin(rand)**3 + (rand/10)**6 +(5-i)**2 #+ 2/rand + 2/rand*2
        func = (rand/2)**2 + (5-i)**2 
        im = plt.plot(func)             # 乱数をグラフにする
        ims.append(im)                  # グラフを配列 ims に追加

# 10枚のプロットを 100ms ごとに表示
ani = animation.ArtistAnimation(fig, ims, interval=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()

def plot(data):
    plt.cla()                      # 現在描写されているグラフを消去
    rand = np.random.randn(100)    # 100個の乱数を生成
    im = plt.plot(rand)            # グラフを生成

def plot2(data):
    plt.cla()                      # 現在描写されているグラフを消去
    rand = np.random.randn(100)    # 100個の乱数を生成
    im = plt.plot(rand)
    rand = np.random.randn(100)/10    # 100個の乱数を生成
    im2 = plt.plot(rand,'r')            # グラフを生成

#ani = animation.FuncAnimation(fig, plot, interval=100)
ani = animation.FuncAnimation(fig, plot2, interval=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
