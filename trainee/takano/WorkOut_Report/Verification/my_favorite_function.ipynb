# %% [markdown]
# # 好きな関数を3つ表示する（二次元）

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0.0, 5.0)
y = np.tan(x)

plt.plot(x, y, '-')
plt.title('tan')

plt.show()

# %% [markdown]
# #### tanを表示

# %%
# import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
delta = 0.025
xrange = np.arange(-3, 3, delta)
yrange = np.arange(-3, 3, delta)
X, Y = np.meshgrid(xrange,yrange)

#for x, y in zip(X, Y):
#print(*zip(x, y))

#軸の設定
plt.axis([-3, 3, -3, 3])
plt.gca().set_aspect('equal', adjustable='box')

#print(X)
#print(Y)
#描画
#Z=X**2+Y**2-1
Z=X**2+(Y-np.sqrt(np.abs(X)))**2-1
x=pd.DataFrame(X)
y=pd.DataFrame(Y)
z=pd.DataFrame(Z)
#display(x)
#display(y)
#display(z)
plt.contourf(X, Y, Z)
plt.show()

# %% [markdown]
# #### ハートの形を表す関数 contourという等高線を書くコマンドを使った。2次元平面上でメッシュと等高線を合わせることで、円の表示が行えそう。

# %%
r = np.arange(0, 2, 0.01)
theta = np.exp(r)**2

ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  
ax.set_rlabel_position(-22.5) 
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %% [markdown]
# #### 極座標上で色々いじったら不思議なグラフができた

# %% [markdown]
# # 好きな関数を表示(3次元)

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-3, 3, 0.01)
y = np.arange(-3, 3, 0.01)
X, Y = np.meshgrid(x, y)
print(X,Y)
Z =np.exp(-(X**2+Y**2))

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_wireframe(X,Y,Z)

plt.show()
# Out:
# [[-3.   -2.99 -2.98 ...  2.97  2.98  2.99]
#  [-3.   -2.99 -2.98 ...  2.97  2.98  2.99]
#  [-3.   -2.99 -2.98 ...  2.97  2.98  2.99]
#  ...
#  [-3.   -2.99 -2.98 ...  2.97  2.98  2.99]
#  [-3.   -2.99 -2.98 ...  2.97  2.98  2.99]
#  [-3.   -2.99 -2.98 ...  2.97  2.98  2.99]] [[-3.   -3.   -3.   ... -3.   -3.   -3.  ]
#  [-2.99 -2.99 -2.99 ... -2.99 -2.99 -2.99]
#  [-2.98 -2.98 -2.98 ... -2.98 -2.98 -2.98]
#  ...
#  [ 2.97  2.97  2.97 ...  2.97  2.97  2.97]
#  [ 2.98  2.98  2.98 ...  2.98  2.98  2.98]
#  [ 2.99  2.99  2.99 ...  2.99  2.99  2.99]]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### シンプルで分かりやすい形をしてるので好き 3次元上ではメッシュの使い方は直感的に理解できた

# %% [markdown]
# # アニメーションで関数を動かす

# %%
import matplotlib.animation as anm
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

fig = plt.figure(figsize = (10, 6))
x = np.arange(-10, 10, 0.1)

def update(i, fig_title, A):
    plt.cla()                      # 現在描写されているグラフを消去

    y = A*x**(i*2)
    plt.plot(x, y, "r")
    plt.title(fig_title + 'i=' + str(i))


ani = anm.FuncAnimation(fig, update, fargs = ('Initial Animation! ', 2.0), \
    interval = 1000, frames = 10)
display(HTML(ani.to_html5_video()))
# Out:
# <video width="1000" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# #### グラフを動かしているというより、関数を変更させているだけなので題意に沿っていないかも
